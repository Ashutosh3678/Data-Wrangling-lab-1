# %% [markdown]
# <a href="https://colab.research.google.com/github/Ashutosh3678/Data-Wrangling-lab-1/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World")
# Out:
# Hello World

# %%
age = 20
if age >= 18:
  print("You are an adult")
else:
  print("You are a minor")
# Out:
# You are an adult

# %%
import numpy as np
matrix1 = np.array([[1, 2], [3, 4]])
matrix2 = np.array([[5, 6], [7, 8]])
result = np.add(matrix1, matrix2)
print("Resultant matrix is:")
print(result)
# Out:
# Resultant matrix is:
# [[ 6  8]
#  [10 12]]

# %%
import pandas as pd
import numpy as np

data= pd.read_csv("/content/fashionnova_reviews.csv")
data.head()
data.tail()
# Out:
#               Reviewer Name                     Profile Link Country  \
# 131975       nyakenya mayan  /users/583c12ec0000ff000a5ba836      US
# 131976        Tiffany Picou  /users/583b6b420000ff000a5b8a0f      US
# 131977  Amani Keyes-Fortson  /users/583b597f0000ff000a5b86ca      US
# 131978    Suryely Hernandez  /users/583b3a690000ff000a5b7f10      US
# 131979      Ashlee Ann Tyra  /users/583b39d90000ff000a5b7ede      US
#
#        Review Count               Review Date                  Rating  \
# 131975     1 review  2016-11-28T11:20:27.000Z  Rated 1 out of 5 stars
# 131976     1 review  2016-11-27T23:25:02.000Z  Rated 5 out of 5 stars
# 131977     1 review  2016-11-27T22:09:55.073Z  Rated 5 out of 5 stars
# 131978     1 review  2016-11-27T19:56:35.000Z  Rated 5 out of 5 stars
# 131979    2 reviews  2016-11-27T19:54:08.000Z  Rated 5 out of 5 stars
#
#                                              Review Title  \
# 131975                         My experience was horrible
# ...

# %%
import pandas as pd
import numpy as np
data=pd.read_csv("/content/fashionnova_reviews.csv")
data.describe()
# Out:
#        Reviewer Name                     Profile Link Country Review Count  \
# count         131917                           131980  131976       131980
# unique        111453                           131914     181           56
# top         customer  /users/64b81c2e4b86b400126ce1a8      US     1 review
# freq             994                                2  121912        92203
#
#                      Review Date                  Rating Review Title  \
# count                     131980                  131980       131932
# unique                    131616                       5        90452
# top     2023-07-19T19:23:59.000Z  Rated 5 out of 5 stars        Great
# freq                           3                   90874         2240
#
#                   Review Text Date of Experience
# count                  131980             131980
# unique                  91107               2595
# top     Review text not found  November 25, 2022
# ...
